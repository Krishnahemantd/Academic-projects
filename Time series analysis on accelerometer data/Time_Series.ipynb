# %% [markdown]
# **KRISHNA HEMANT AND DIVYANGANA PANDEY PROJECT 3 TASK 1**

# %%
# !pip install ts2vg
# !pip install igraph
# !pip install pycairo
# !pip install cairocffi


import numpy as np
from re import M
from os import name
from numpy.core.multiarray import result_type
 
import seaborn as sns
# Out:
# ...
#      |████████████████████████████████| 1.0 MB 7.4 MB/s
# ...
#      |████████████████████████████████| 3.2 MB 6.8 MB/s
# ...
#      |████████████████████████████████| 344 kB 7.0 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   ERROR: Failed building wheel for pycairo
# Failed to build pycairo
# ERROR: Could not build wheels for pycairo which use PEP 517 and cannot be installed directly
# ...
#      |████████████████████████████████| 88 kB 4.9 MB/s
# ...
#   Created wheel for cairocffi: filename=cairocffi-1.3.0-py3-none-any.whl size=89667 sha256=aa4677eef3774e9099c9fc251e256a5fdb59efd8d86ec913d40ef63a389c1d0a
#   Stored in directory: /root/.cache/pip/wheels/4e/ca/e1/5c8a9692a27f639a07c949044bec943f26c81cd53d3805319f
# Successfully built cairocffi
# ...

# %% [markdown]
# 1. Apply natural visibility graph (NVG) and horizontal visibility graph (HVG) to the aforementioned data
# 2. Compute average degree, network diameter, and average path length
# 3. For the above computations select sample size of 1024 data points ( from 1000
# to 2024) for each of the 15 time series

# %%
from ts2vg import NaturalVG
def NVG(df):
  g = NaturalVG()
  g.build(df[1000:2024])
  ig_g = g.as_igraph()
  degree=np.mean(ig_g.degree())
  diameter=ig_g.diameter()
  avg_len=ig_g.average_path_length()
  return degree, diameter,avg_len

# %%
from ts2vg import HorizontalVG
def HVG(df):
  g = HorizontalVG()
  g.build(df[1000:2024])
  ig_g = g.as_igraph()
  degree=np.mean(ig_g.degree())
  diameter=ig_g.diameter()
  avg_len=ig_g.average_path_length()
  return degree, diameter,avg_len

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2558667c-3f0d-4ef8-93b8-849089103ef8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2558667c-3f0d-4ef8-93b8-849089103ef8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving acc_climbingdown_chest_1.csv to acc_climbingdown_chest_1.csv
# Saving acc_climbingdown_chest_2.csv to acc_climbingdown_chest_2.csv
# Saving acc_climbingdown_chest_3.csv to acc_climbingdown_chest_3.csv
# Saving acc_climbingdown_chest_4.csv to acc_climbingdown_chest_4.csv
# Saving acc_climbingdown_chest_5.csv to acc_climbingdown_chest_5.csv
# Saving acc_climbingdown_chest_6.csv to acc_climbingdown_chest_6.csv
# Saving acc_climbingdown_chest_7.csv to acc_climbingdown_chest_7.csv
# Saving acc_climbingdown_chest_8.csv to acc_climbingdown_chest_8.csv
# ...

# %%
import pandas as pd
walking1 = pd.read_csv('acc_walking_chest_1.csv')
walking2 = pd.read_csv('acc_walking_chest_2.csv')
walking3 = pd.read_csv('acc_walking_chest_3.csv')
walking4 = pd.read_csv('acc_walking_chest_4.csv')
walking5 = pd.read_csv('acc_walking_chest_5.csv')
walking6 = pd.read_csv('acc_walking_chest_6.csv')
walking7 = pd.read_csv('acc_walking_chest_7.csv')
walking8 = pd.read_csv('acc_walking_chest_8.csv')
walking9 = pd.read_csv('acc_walking_chest_9.csv')
walking10 = pd.read_csv('acc_walking_chest_10.csv')
walking11 = pd.read_csv('acc_walking_chest_11.csv')
walking12 = pd.read_csv('acc_walking_chest_12.csv')
walking13 = pd.read_csv('acc_walking_chest_13.csv')
walking14 = pd.read_csv('acc_walking_chest_14.csv')
walking15 = pd.read_csv('acc_walking_chest_15.csv')

running1 = pd.read_csv('acc_running_chest_1.csv')
running2 = pd.read_csv('acc_running_chest_2.csv')
running3 = pd.read_csv('acc_running_chest_3.csv')
running4 = pd.read_csv('acc_running_chest_4.csv')
running5 = pd.read_csv('acc_running_chest_5.csv')
running6 = pd.read_csv('acc_running_chest_6.csv')
running7 = pd.read_csv('acc_running_chest_7.csv')
running8 = pd.read_csv('acc_running_chest_8.csv')
running9 = pd.read_csv('acc_running_chest_9.csv')
running10 = pd.read_csv('acc_running_chest_10.csv')
running11 = pd.read_csv('acc_running_chest_11.csv')
running12 = pd.read_csv('acc_running_chest_12.csv')
running13 = pd.read_csv('acc_running_chest_13.csv')
running14 = pd.read_csv('acc_running_chest_14.csv')
running15 = pd.read_csv('acc_running_chest_15.csv')

climbingup1 = pd.read_csv('acc_climbingup_chest_1.csv')
climbingup2 = pd.read_csv('acc_climbingup_chest_2.csv')
climbingup3 = pd.read_csv('acc_climbingup_chest_3.csv')
climbingup4 = pd.read_csv('acc_climbingup_chest_4.csv')
climbingup5 = pd.read_csv('acc_climbingup_chest_5.csv')
climbingup6 = pd.read_csv('acc_climbingup_chest_6.csv')
climbingup7 = pd.read_csv('acc_climbingup_chest_7.csv')
climbingup8 = pd.read_csv('acc_climbingup_chest_8.csv')
climbingup9 = pd.read_csv('acc_climbingup_chest_9.csv')
climbingup10 = pd.read_csv('acc_climbingup_chest_10.csv')
climbingup11 = pd.read_csv('acc_climbingup_chest_11.csv')
climbingup12 = pd.read_csv('acc_climbingup_chest_12.csv')
climbingup13 = pd.read_csv('acc_climbingup_chest_13.csv')
climbingup14 = pd.read_csv('acc_climbingup_chest_14.csv')
climbingup15 = pd.read_csv('acc_climbingup_chest_15.csv')

climbingdown1 = pd.read_csv('acc_climbingdown_chest_1.csv')
climbingdown2 = pd.read_csv('acc_climbingdown_chest_2.csv')
climbingdown3 = pd.read_csv('acc_climbingdown_chest_3.csv')
climbingdown4 = pd.read_csv('acc_climbingdown_chest_4.csv')
climbingdown5 = pd.read_csv('acc_climbingdown_chest_5.csv')
climbingdown6 = pd.read_csv('acc_climbingdown_chest_6.csv')
climbingdown7 = pd.read_csv('acc_climbingdown_chest_7.csv')
climbingdown8 = pd.read_csv('acc_climbingdown_chest_8.csv')
climbingdown9 = pd.read_csv('acc_climbingdown_chest_9.csv')
climbingdown10 = pd.read_csv('acc_climbingdown_chest_10.csv')
climbingdown11 = pd.read_csv('acc_climbingdown_chest_11.csv')
climbingdown12 = pd.read_csv('acc_climbingdown_chest_12.csv')
climbingdown13 = pd.read_csv('acc_climbingdown_chest_13.csv')
climbingdown14 = pd.read_csv('acc_climbingdown_chest_14.csv')
climbingdown15 = pd.read_csv('acc_climbingdown_chest_15.csv')

# %% [markdown]
# **Tabulate all the results**

# %%
all_files = {'walking_1' : walking1, 'running_1' : running1, 'climbingup_1': climbingup1, 'climbingdown_1' : climbingdown1,
       'walking_2' : walking2, 'running_2' : running2, 'climbingup_2': climbingup2, 'climbingdown_2' : climbingdown2,
       'walking_3' : walking3, 'running_3' : running3, 'climbingup_3': climbingup3, 'climbingdown_3' : climbingdown3,
       'walking_4' : walking4, 'running_4' : running4, 'climbingup_4': climbingup4, 'climbingdown_4' : climbingdown4,
       'walking_5' : walking5, 'running_5' : running5, 'climbingup_5': climbingup5, 'climbingdown_5' : climbingdown5,
       'walking_6' : walking6, 'running_6' : running6, 'climbingup_6': climbingup6, 'climbingdown_6' : climbingdown6,
       'walking_7' : walking7, 'running_7' : running7, 'climbingup_7': climbingup7, 'climbingdown_7' : climbingdown7,
       'walking_8' : walking8, 'running_8' : running8, 'climbingup_8': climbingup8, 'climbingdown_8' : climbingdown8,
       'walking_9' : walking9, 'running_9' : running9, 'climbingup_9': climbingup9, 'climbingdown_9' : climbingdown9,
       'walking_10' : walking10, 'running_10' : running10, 'climbingup_10': climbingup10, 'climbingdown_10' : climbingdown10,
       'walking_11' : walking11, 'running_11' : running11, 'climbingup_11': climbingup11, 'climbingdown_11' : climbingdown11,
       'walking_12' : walking12, 'running_12' : running12, 'climbingup_12': climbingup12, 'climbingdown_12' : climbingdown12,
       'walking_13' : walking13, 'running_13' : running13, 'climbingup_13': climbingup13, 'climbingdown_13' : climbingdown13,
       'walking_14' : walking14, 'running_14' : running14, 'climbingup_14': climbingup14, 'climbingdown_14' : climbingdown14,
       'walking_15' : walking15, 'running_15' : running15, 'climbingup_15': climbingup15, 'climbingdown_15' : climbingdown15,
       }
df = pd.DataFrame([])
data = []
attributes = ["attr_x","attr_y","attr_z"]
columns = ["Activity_subject","Direction","NVG_Degree","NVG_diam","NVG_avglen","HVG_Degree","HVG_diam","HVG_avglen"]

for a,b in all_files.items():
  for i in attributes:      
    NVG_Degree, NVG_diam, NVG_avglen = NVG(b[i])
    HVG_Degree, HVG_diam, HVG_avglen = HVG(b[i])
    values = (a,i,NVG_Degree,NVG_diam,NVG_avglen,HVG_Degree,HVG_diam,HVG_avglen)
    zipped = zip(columns, values)
    task1_dictionary = dict(zipped)
    data.append(task1_dictionary)
df = df.append(data, True)

conditions_activities= [
       (df['Activity_subject'].str.contains('walking', case=False, na=False)),
       (df['Activity_subject'].str.contains('running', case=False, na=False)),
       (df['Activity_subject'].str.contains('climbingup', case=False, na=False)),
       (df['Activity_subject'].str.contains('climbingdown', case=False, na=False))
       ]
conditions_axis = [
       (df['Direction'].str.contains('x', case=False, na=False)),
       (df['Direction'].str.contains('y', case=False, na=False)),
       (df['Direction'].str.contains('z', case=False, na=False)),  
]
choices = ['Walk','Run','ClimbUp','ClimbDown']
choices_axis = ['X','Y','Z']
df['Type'] = np.select(conditions_activities, choices, default=0)
df['Axis'] = np.select(conditions_axis, choices_axis, default=0)
df
# Out:
#     Activity_subject Direction  NVG_Degree  ...  HVG_avglen       Type  Axis
# 0          walking_1    attr_x   11.451172  ...   11.578024       Walk     X
# 1          walking_1    attr_y   11.986328  ...   10.666252       Walk     Y
# 2          walking_1    attr_z    8.570312  ...   10.602296       Walk     Z
# 3          running_1    attr_x    8.414062  ...    7.543843        Run     X
# 4          running_1    attr_y   11.136719  ...   31.634922        Run     Y
# ..               ...       ...         ...  ...         ...        ...   ...
# 175    climbingup_15    attr_y   13.744141  ...   13.796356    ClimbUp     Y
# 176    climbingup_15    attr_z   10.123047  ...   11.595193    ClimbUp     Z
# 177  climbingdown_15    attr_x   11.130859  ...   13.926625  ClimbDown     X
# 178  climbingdown_15    attr_y   14.156250  ...   13.582100  ClimbDown     Y
# 179  climbingdown_15    attr_z    8.955078  ...   11.783465  ClimbDown     Z
#
# [180 rows x 10 columns]

# %% [markdown]
# Generate  scatter plots: average degree vs network diameter and color the pointsaccording to walking and running

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

walk_run_x = df['Type'].str.contains('Walk|Run', case=False, na=False) & df['Direction'].str.contains('attr_x', case=False, na=False)
df_walk_run_x = df[walk_run_x]
walk_run_y = df['Type'].str.contains('Walk|Run', case=False, na=False) & df['Direction'].str.contains('attr_y', case=False, na=False)
df_walk_run_y = df[walk_run_y]
walk_run_z = df['Type'].str.contains('Walk|Run', case=False, na=False) & df['Direction'].str.contains('attr_z', case=False, na=False)
df_walk_run_z = df[walk_run_z]

# X axis
sns.scatterplot(data=df_walk_run_x, x="NVG_Degree", y="NVG_diam", hue="Type").set(title = 'Walking and Running data X direction')
plt.show()
sns.scatterplot(data=df_walk_run_x, x="HVG_Degree", y="HVG_diam", hue="Type").set(title = 'Walking and Running data X direction')
plt.show()

# Y axis
sns.scatterplot(data=df_walk_run_y, x="NVG_Degree", y="NVG_diam", hue="Type").set(title = 'Walking and Running data Y direction')
plt.show()
sns.scatterplot(data=df_walk_run_y, x="HVG_Degree", y="HVG_diam", hue="Type").set(title = 'Walking and Running data Y direction')
plt.show()

# Z axis
sns.scatterplot(data=df_walk_run_z, x="NVG_Degree", y="NVG_diam", hue="Type").set(title = 'Walking and Running data Z direction')
plt.show()
sns.scatterplot(data=df_walk_run_z, x="HVG_Degree", y="HVG_diam", hue="Type").set(title = 'Walking and Running data Z direction')
plt.show()

# %% [markdown]
# Generate  scatter plots: average degree vs network diameter and color the points according to climbing up and climbing down

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

climb_updown_x = df['Type'].str.contains('ClimbUp|ClimbDown', case=False, na=False) & df['Direction'].str.contains('attr_x', case=False, na=False)
df_climb_updown_x = df[climb_updown_x]
climb_updown_y = df['Type'].str.contains('ClimbUp|ClimbDown', case=False, na=False) & df['Direction'].str.contains('attr_y', case=False, na=False)
df_climb_updown_y = df[climb_updown_y]
climb_updown_z = df['Type'].str.contains('ClimbUp|ClimbDown', case=False, na=False) & df['Direction'].str.contains('attr_z', case=False, na=False)
df_climb_updown_z = df[climb_updown_z]

# X axis
sns.scatterplot(data=df_climb_updown_x, x="NVG_Degree", y="NVG_diam", hue="Type").set(title = 'ClimbUp and ClimbDown data X direction')
plt.show()
sns.scatterplot(data=df_climb_updown_x, x="HVG_Degree", y="HVG_diam", hue="Type").set(title = 'ClimbUp and ClimbDown data X direction')
plt.show()

# Y axis
sns.scatterplot(data=df_climb_updown_y, x="NVG_Degree", y="NVG_diam", hue="Type").set(title = 'ClimbUp and ClimbDown data Y direction')
plt.show()
sns.scatterplot(data=df_climb_updown_y, x="HVG_Degree", y="HVG_diam", hue="Type").set(title = 'ClimbUp and ClimbDown data Y direction')
plt.show()

# Z axis
sns.scatterplot(data=df_climb_updown_z, x="NVG_Degree", y="NVG_diam", hue="Type").set(title = 'ClimbUp and ClimbDown data Z direction')
plt.show()
sns.scatterplot(data=df_climb_updown_z, x="HVG_Degree", y="HVG_diam", hue="Type").set(title = 'ClimbUp and ClimbDown data Z direction')
plt.show()

# %% [markdown]
# **KRISHNA HEMANT AND DIVYANGANA PANDEY PROJECT 3 TASK 2**

# %%
import numpy as np


def s_entropy(freq_list):
    ''' This function computes the shannon entropy of a given frequency distribution.
    USAGE: shannon_entropy(freq_list)
    ARGS: freq_list = Numeric vector representing the frequency distribution
    OUTPUT: A numeric value representing shannon's entropy'''
    freq_list = [element for element in freq_list if element != 0]
    sh_entropy = 0.0
    for freq in freq_list:
        sh_entropy += freq * np.log(freq)
    sh_entropy = -sh_entropy
    return(sh_entropy)

def ordinal_patterns(ts, embdim, embdelay):
    ''' This function computes the ordinal patterns of a time series for a given embedding dimension and embedding delay.
    USAGE: ordinal_patterns(ts, embdim, embdelay)
    ARGS: ts = Numeric vector representing the time series, embdim = embedding dimension (3<=embdim<=7 prefered range), embdelay =  embdding delay
    OUPTUT: A numeric vector representing frequencies of ordinal patterns'''
    m, t = embdim, embdelay
    x = ts if isinstance(ts, np.ndarray) else np.array(ts) 

    tmp = np.zeros((x.shape[0], m))
    for i in range(m):
        tmp[:, i] = np.roll(x, i*t)
    partition = tmp[(t*m-1):, :] 
    permutation = np.argsort(partition)
    idx = _hash(permutation)

    counts = np.zeros(np.math.factorial(m))
    for i in range(counts.shape[0]):
        counts[i] = (idx == i).sum()
    return list(counts[counts != 0].astype(int))

def _hash(x):
    m, n = x.shape
    if n == 1:
        return np.zeros(m)
    return np.sum(np.apply_along_axis(lambda y: y < x[:, 0], 0, x), axis=1) * np.math.factorial(n-1) + _hash(x[:, 1:]) 
    

def p_entropy(op):
    ordinal_pat = op
    max_entropy = np.log(len(ordinal_pat))
    p = np.divide(np.array(ordinal_pat), float(sum(ordinal_pat)))
    return(s_entropy(p)/max_entropy)

def complexity(op):
    ''' This function computes the complexity of a time series defined as: Comp_JS = Q_o * JSdivergence * pe
    Q_o = Normalizing constant
    JSdivergence = Jensen-Shannon divergence
    pe = permutation entopry
    ARGS: ordinal pattern'''
    pe = p_entropy(op)
    constant1 = (0.5+((1 - 0.5)/len(op)))* np.log(0.5+((1 - 0.5)/len(op)))
    constant2 = ((1 - 0.5)/len(op))*np.log((1 - 0.5)/len(op))*(len(op) - 1)
    constant3 = 0.5*np.log(len(op))
    Q_o = -1/(constant1+constant2+constant3)

    temp_op_prob = np.divide(op, sum(op))
    temp_op_prob2 = (0.5*temp_op_prob)+(0.5*(1/len(op)))
    JSdivergence = (s_entropy(temp_op_prob2) - 0.5 * s_entropy(temp_op_prob) - 0.5 * np.log(len(op)))
    Comp_JS = Q_o * JSdivergence * pe
    return(Comp_JS)

# %% [markdown]
# PART 1 AND 2) Creating a dataframe with all combinations of Signal, Dimension and Delay for all three axes for all 15 subjects with different activites and adding columns for Permutation Entropy and Complexity

# %%
from re import M
from os import name
from numpy.core.multiarray import result_type
attr = ["attr_x","attr_y","attr_z"]
Em_dim = [3,4,5,6]
Em_de = [1,2,3]
signal = [1024,2048,4096]

dff = {'walking1' : walking1, 'running1' : running1, 'climbingup1': climbingup1, 'climbingdown1' : climbingdown1,'walking2' : walking2, 'running2' : running2, 'climbingup2': climbingup2, 'climbingdown2' : climbingdown2,'walking3' : walking3, 'running3' : running3, 'climbingup3': climbingup3, 'climbingdown3' : climbingdown3,'walking4' : walking4, 'running4' : running4, 'climbingup4': climbingup4, 'climbingdown4' : climbingdown4,'walking5' : walking5, 'running5' : running5, 'climbingup5': climbingup5, 'climbingdown5' : climbingdown5, 'walking6' : walking6, 'running6' : running6, 'climbingup6': climbingup6, 'climbingdown6' : climbingdown6, 'walking7' : walking7, 'running7' : running7, 'climbingup7': climbingup7, 'climbingdown7' : climbingdown7, 'walking8' : walking8, 'running8' : running8, 'climbingup8': climbingup8, 'climbingdown8' : climbingdown8,'walking9' : walking9, 'running9' : running9, 'climbingup9': climbingup9, 'climbingdown9' : climbingdown9, 'walking10' : walking10, 'running10' : running10, 'climbingup10': climbingup10, 'climbingdown10' : climbingdown10,'walking11' : walking11, 'running11' : running11, 'climbingup11': climbingup11, 'climbingdown11' : climbingdown11,'walking12' : walking12, 'running12' : running12, 'climbingup12': climbingup12, 'climbingdown12' : climbingdown12, 'walking13' : walking13, 'running13' : running13, 'climbingup13': climbingup13, 'climbingdown13' : climbingdown13, 'walking14' : walking14, 'running14' : running14, 'climbingup14': climbingup14, 'climbingdown14' : climbingdown14, 'walking15' : walking15, 'running15' : running15, 'climbingup15': climbingup15, 'climbingdown15' : climbingdown15}
df = pd.DataFrame([])
data = []
columns = ["names","direction","signal","Em_dimension","Em_delay","P_entropy","complexity"]
dataa = []
for a,b in dff.items():
  for i in attr:
    for j in signal:
      for k in Em_dim:
          for l in Em_de:        
              op_walking = ordinal_patterns(b[i][0:j],k,l)
              walking_pentropy = p_entropy(op_walking)
              walking_complexity = complexity(op_walking)    
              values = (a,i,j,k,l,walking_pentropy,walking_complexity)
              zipped = zip(columns, values)
              a_dictionary = dict(zipped)
              data.append(a_dictionary)
df = df.append(data, True)
df
# Out:
#                names direction  signal  ...  Em_delay  P_entropy  complexity
# 0           walking1    attr_x    1024  ...         1   0.855987    0.119191
# 1           walking1    attr_x    1024  ...         2   0.960568    0.036283
# 2           walking1    attr_x    1024  ...         3   0.982132    0.016977
# 3           walking1    attr_x    1024  ...         1   0.794190    0.199622
# 4           walking1    attr_x    1024  ...         2   0.926945    0.085968
# ...              ...       ...     ...  ...       ...        ...         ...
# 6475  climbingdown15    attr_z    4096  ...         2   0.942501    0.094303
# 6476  climbingdown15    attr_z    4096  ...         3   0.972191    0.050053
# 6477  climbingdown15    attr_z    4096  ...         1   0.844734    0.238611
# 6478  climbingdown15    attr_z    4096  ...         2   0.935939    0.135029
# 6479  climbingdown15    attr_z    4096  ...         3   0.962741    0.085106
#
# [6480 rows x 7 columns]

# %% [markdown]
# Filtering main dataframe and creating seperate dataframes for plotting purposes

# %%
dfwr = df[df['names'].str.contains('walking|running')]
dfclimbing = df[df['names'].str[0].isin(['c'])]
filtered_dfwr = dfwr[(dfwr["signal"]== 4096) & (dfwr["Em_delay"]== 1)]
filtered_climbing = dfclimbing[(dfclimbing["signal"]== 4096) & (dfclimbing["Em_delay"]== 1)]
#filw = filtered_dfwr[filtered_dfwr['names'].str[0].isin(['w'])]
#filr = filtered_dfwr[filtered_dfwr['names'].str[0].isin(['r'])]
display(filtered_dfwr)
display(filtered_climbing)
# Out:
#           names direction  signal  ...  Em_delay  P_entropy  complexity
# 24     walking1    attr_x    4096  ...         1   0.830818    0.136888
# 27     walking1    attr_x    4096  ...         1   0.760063    0.226481
# 30     walking1    attr_x    4096  ...         1   0.743251    0.288125
# 33     walking1    attr_x    4096  ...         1   0.782974    0.287738
# 60     walking1    attr_y    4096  ...         1   0.771098    0.170549
# ...         ...       ...     ...  ...       ...        ...         ...
# 6225  running15    attr_y    4096  ...         1   0.645114    0.311300
# 6252  running15    attr_z    4096  ...         1   0.942847    0.051778
# 6255  running15    attr_z    4096  ...         1   0.905373    0.111704
# 6258  running15    attr_z    4096  ...         1   0.876156    0.188441
# 6261  running15    attr_z    4096  ...         1   0.891348    0.200250
#
# [360 rows x 7 columns]
#                names direction  signal  ...  Em_delay  P_entropy  complexity
# ...

# %% [markdown]
# Resetting indexes for ease

# %%
filtered_dfwr = filtered_dfwr.reset_index(drop = True)
filtered_climbing = filtered_climbing.reset_index(drop = True)

# %% [markdown]
# Changing values of columns to (walking/running) or (climbingup/climbingdown) for color coded plotting

# %%
names = []
for idx, row in filtered_dfwr.iterrows():

  if "walking" in row['names']:
    names.append('walking')
  elif "running" in row['names']:
    names.append('running')

# %%
namess = []
for idx, row in filtered_climbing.iterrows():

  if "climbingup" in row['names']:
    namess.append('climbingup')
  elif "climbingdown" in row['names']:
    namess.append('climbingdown')

# %%
filtered_dfwr['names_updated'] = names
filtered_climbing['updated_names'] = namess
#filtered_climbing = filtered_climbing[['updated_names','P_entropy','complexity']]
#filtered_dfwr = filtered_dfwr[['names_updated', 'direction', 'P_entropy', 'complexity']]

# %% [markdown]
# Creating multiple data frames for plotting purposes varying Embedded dimension and axes

# %%
dfwr1 = filtered_dfwr[(filtered_dfwr["direction"]== 'attr_x') & (filtered_dfwr["Em_dimension"]== 3)]
dfwr2 = filtered_dfwr[(filtered_dfwr["direction"]== 'attr_x') & (filtered_dfwr["Em_dimension"]== 4)]
dfwr3 = filtered_dfwr[(filtered_dfwr["direction"]== 'attr_x') & (filtered_dfwr["Em_dimension"]== 5)]
dfwr4 = filtered_dfwr[(filtered_dfwr["direction"]== 'attr_x') & (filtered_dfwr["Em_dimension"]== 6)]
dfwr5 = filtered_dfwr[(filtered_dfwr["direction"]== 'attr_y') & (filtered_dfwr["Em_dimension"]== 3)]
dfwr6 = filtered_dfwr[(filtered_dfwr["direction"]== 'attr_y') & (filtered_dfwr["Em_dimension"]== 4)] 
dfwr7 = filtered_dfwr[(filtered_dfwr["direction"]== 'attr_y') & (filtered_dfwr["Em_dimension"]== 5)]
dfwr8 = filtered_dfwr[(filtered_dfwr["direction"]== 'attr_y') & (filtered_dfwr["Em_dimension"]== 6)]
dfwr9 = filtered_dfwr[(filtered_dfwr["direction"]== 'attr_z') & (filtered_dfwr["Em_dimension"]== 3)]
dfwr10 = filtered_dfwr[(filtered_dfwr["direction"]== 'attr_z') & (filtered_dfwr["Em_dimension"]== 4)]
dfwr11 = filtered_dfwr[(filtered_dfwr["direction"]== 'attr_z') & (filtered_dfwr["Em_dimension"]== 5)]
dfwr12 = filtered_dfwr[(filtered_dfwr["direction"]== 'attr_z') & (filtered_dfwr["Em_dimension"]== 6)]

# %%
climbing1 = filtered_climbing[(filtered_climbing["direction"]== 'attr_x') & (filtered_climbing["Em_dimension"]== 3)]
climbing2 = filtered_climbing[(filtered_climbing["direction"]== 'attr_x') & (filtered_climbing["Em_dimension"]== 4)]
climbing3 = filtered_climbing[(filtered_climbing["direction"]== 'attr_x') & (filtered_climbing["Em_dimension"]== 5)]
climbing4 = filtered_climbing[(filtered_climbing["direction"]== 'attr_x') & (filtered_climbing["Em_dimension"]== 6)]
climbing5 = filtered_climbing[(filtered_climbing["direction"]== 'attr_y') & (filtered_climbing["Em_dimension"]== 3)]
climbing6 = filtered_climbing[(filtered_climbing["direction"]== 'attr_y') & (filtered_climbing["Em_dimension"]== 4)] 
climbing7 = filtered_climbing[(filtered_climbing["direction"]== 'attr_y') & (filtered_climbing["Em_dimension"]== 5)]
climbing8 = filtered_climbing[(filtered_climbing["direction"]== 'attr_y') & (filtered_climbing["Em_dimension"]== 6)]
climbing9 = filtered_climbing[(filtered_climbing["direction"]== 'attr_z') & (filtered_climbing["Em_dimension"]== 3)]
climbing10 = filtered_climbing[(filtered_climbing["direction"]== 'attr_z') & (filtered_climbing["Em_dimension"]== 4)]
climbing11 = filtered_climbing[(filtered_climbing["direction"]== 'attr_z') & (filtered_climbing["Em_dimension"]== 5)]
climbing12 = filtered_climbing[(filtered_climbing["direction"]== 'attr_z') & (filtered_climbing["Em_dimension"]== 6)]

# %% [markdown]
# **PART 3** Using seaborn to plot 12 scatter plots(walking and running) for Permutation Entropy vs Complexity data -> Signal length 4096 and Delay 1

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(data=dfwr1, x="complexity", y="P_entropy", hue="names_updated").set(title = 'Walking and Running data X,DIM3')
plt.show()

sns.scatterplot(data=dfwr2, x="complexity", y="P_entropy", hue="names_updated").set(title = 'Walking and Running data X,DIM4')
plt.show()

sns.scatterplot(data=dfwr3, x="complexity", y="P_entropy", hue="names_updated").set(title = 'Walking and Running data X,DIM5')
plt.show()

sns.scatterplot(data=dfwr4, x="complexity", y="P_entropy", hue="names_updated").set(title = 'Walking and Running data X,DIM6')
plt.show()

sns.scatterplot(data=dfwr5, x="complexity", y="P_entropy", hue="names_updated").set(title = 'Walking and Running data Y,DIM3')
plt.show()

sns.scatterplot(data=dfwr6, x="complexity", y="P_entropy", hue="names_updated").set(title = 'Walking and Running data Y,DIM4')
plt.show()

sns.scatterplot(data=dfwr7, x="complexity", y="P_entropy", hue="names_updated").set(title = 'Walking and Running data Y,DIM5')
plt.show()

sns.scatterplot(data=dfwr8, x="complexity", y="P_entropy", hue="names_updated").set(title = 'Walking and Running data Y,DIM6')
plt.show()

sns.scatterplot(data=dfwr9, x="complexity", y="P_entropy", hue="names_updated").set(title = 'Walking and Running data Z,DIM3')
plt.show()

sns.scatterplot(data=dfwr10, x="complexity", y="P_entropy", hue="names_updated").set(title = 'Walking and Running data Z,DIM4')
plt.show()

sns.scatterplot(data=dfwr11, x="complexity", y="P_entropy", hue="names_updated").set(title = 'Walking and Running data Z,DIM5')
plt.show()

sns.scatterplot(data=dfwr12, x="complexity", y="P_entropy", hue="names_updated").set(title = 'Walking and Running data Z,DIM6')
plt.show()

# %% [markdown]
# **PART 4** Using Seaborn to plot 12 scatter plots(Climbing up and climbing down) for Permutation Entropy vs Complexity data -> Signal length 4096 and Delay 1

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(data=climbing1, x="complexity", y="P_entropy", hue="updated_names").set(title = 'Climbing up and climbing down data X,DIM3')
plt.show()

sns.scatterplot(data=climbing2, x="complexity", y="P_entropy", hue="updated_names").set(title = 'Climbing up and climbing down data X,DIM4')
plt.show()

sns.scatterplot(data=climbing3, x="complexity", y="P_entropy", hue="updated_names").set(title = 'Climbing up and climbing down data X,DIM5')
plt.show()

sns.scatterplot(data=climbing4, x="complexity", y="P_entropy", hue="updated_names").set(title = 'Climbing up and climbing down data X,DIM6')
plt.show()

sns.scatterplot(data=climbing5, x="complexity", y="P_entropy", hue="updated_names").set(title = 'Climbing up and climbing down data Y,DIM3')
plt.show()

sns.scatterplot(data=climbing6, x="complexity", y="P_entropy", hue="updated_names").set(title = 'Climbing up and climbing down data Y,DIM4')
plt.show()

sns.scatterplot(data=climbing7, x="complexity", y="P_entropy", hue="updated_names").set(title = 'Climbing up and climbing down data Y,DIM5')
plt.show()

sns.scatterplot(data=climbing8, x="complexity", y="P_entropy", hue="updated_names").set(title = 'Climbing up and climbing down data Y,DIM6')
plt.show()

sns.scatterplot(data=climbing9, x="complexity", y="P_entropy", hue="updated_names").set(title = 'Climbing up and climbing down data Z,DIM3')
plt.show()

sns.scatterplot(data=climbing10, x="complexity", y="P_entropy", hue="updated_names").set(title = 'Climbing up and climbing down data Z,DIM4')
plt.show()

sns.scatterplot(data=climbing11, x="complexity", y="P_entropy", hue="updated_names").set(title = 'Climbing up and climbing down data Z,DIM5')
plt.show()

sns.scatterplot(data=climbing12, x="complexity", y="P_entropy", hue="updated_names").set(title = 'Climbing up and climbing down data Z,DIM6')
plt.show()
